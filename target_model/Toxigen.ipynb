# %%
import pandas as pd

# %%
df = pd.read_csv('../data/toxigen_train.csv')

# %%
df.target_group.unique()
# Out:
# array(['asian', 'mexican', 'muslim', 'physical_dis', 'jewish',
#        'native_american', 'lgbtq', 'women', 'middle_east', 'chinese',
#        'mental_dis', 'latino', 'black'], dtype=object)

# %%
df = df[df['target_group'].isin(['muslim','jewish','lgbtq','black'])]

# %%
df
# Out:
#                                                    text target_group  \
# 2                              b'muslims deseve to die'       muslim
# 4     b"Jews were all bad people because they're in ...       jewish
# 6     b'first of all, fox news is a joke, as well as...        lgbtq
# 7     b'jews are the only group of people who are to...       jewish
# 21    b'I was born in a shithole country with an idi...       jewish
# ...                                                 ...          ...
# 8937  b'there is a reason they are called the chosen...       jewish
# 8939  b'this is not just a problem in the united sta...        black
# 8942  b'the only way to get rid of racism is to stop...        black
# 8949  b'If you do not believe me, just go to the mid...       muslim
# 8951  b'calling Obama an "ignorant baboon" is "not t...        black
#
#                          factual?                 ingroup_effect  \
# 2     neither factual nor opinion  doesn't use in-group language
# ...

# %%
df.to_csv('../data/toxigen_filtered.csv')
