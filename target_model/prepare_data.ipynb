# %%
import torch
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler
from transformers import BertTokenizer, BertForSequenceClassification, BertConfig
from sklearn.model_selection import train_test_split
from collections import Counter
import pandas as pd
import numpy as np
import json
from tabulate import tabulate
from tqdm import trange
import random
import re
import seaborn as sns
from sklearn.metrics import classification_report, recall_score,precision_score , f1_score, accuracy_score
import sys
sys.path.append("HateRecognition/target_model/")
from utils import preprocessing, load_anno_data, data_loader, define_target, create_model
from bertopic import BERTopic
from TopicTuner.topictuner import TopicModelTuner as TMT
from sklearn.feature_extraction.text import CountVectorizer
from umap import UMAP
from sklearn.model_selection import StratifiedKFold
from hdbscan import HDBSCAN
from sklearn.metrics import confusion_matrix
sys.path.append("../")
from TweetNormalizer import normalizeTweet
import gc
from cleantext import clean
import spacy
from spacy.language import Language
from spacy_langdetect import LanguageDetector

# %%
file_name = "hatexplain_bt"

# %%
df = pd.read_csv(fr'../data/{file_name}.csv', encoding="utf8")
print(df.columns)
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'label', 'target', 'english', 'spanish',
#        'german', 'franch', 'russian', 'chinese'],
#       dtype='object')

# %%
text_col_name = 'body'
target_col_name = 'target'
id_col_name = 'Unnamed: 0'
# rename columns
df.rename(columns={text_col_name:"text"}, inplace=True)
df.rename(columns={target_col_name:"target"}, inplace=True)
df.rename(columns={id_col_name:"id"}, inplace=True)

# %%
df.dropna(axis=0, inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#       Unnamed: 0.1                           id       label   target  \
# 0                3  1179088797964763136_twitter  hatespeech    other
# 1                4  1179085312976445440_twitter  hatespeech    other
# 2                5                 13851720_gab  hatespeech   Jewish
# 3                6                 24198545_gab  hatespeech  African
# 4                8                 19679648_gab  hatespeech  African
# ...            ...                          ...         ...      ...
# 6119         20123                  9845733_gab  hatespeech   Jewish
# 6120         20128                  9867117_gab  hatespeech    Islam
# 6121         20134                  9875482_gab  hatespeech  African
# 6122         20140                  9982674_gab  hatespeech    Islam
# 6123         20146                  9992513_gab  hatespeech    other
#
#                                                 english  \
# 0     <user> i am bit confused coz chinese ppl can n...
# 1     this bitch in whataburger eating a burger with...
# 2     laura loomer raped me while screaming at me in...
# 3     and this is why i end up with nigger trainee d...
# 4     guilty until proven innocent unless you are a ...
# ...                                                 ...
# 6119  do not for get my followers the jews have decl...
# 6120  well my dear lgbtq brothers and sisters i do n...
# 6121  c mon men charge it for the gays trannies musl...
# 6122  more and more leftists are moving closer to ce...
# 6123  it is awful look at world demographics asians ...
#
#                                                 spanish  \
# 0     <user> i 'm a little confused chinese coz ppl ...
# 1     this bitch in whaaburger eating a hamburger wi...
# 2     laura loomer raped me while screaming at me in...
# 3     and that 's why i end up with black doctors wh...
# 4     guilty until proven innocent unless you are a ...
# ...                                                 ...
# 6119  not to get my followers the jews have declared...
# 6120  well , dear brothers and sisters lgbtq , i do ...
# 6121  men charge it for gay transsexual muslim rapis...
# 6122  more and more leftists are getting closer to t...
# 6123  it 's a horrible look at world demography asia...
#
#                                                  german  \
# 0     i 'm a little confused coz chinese ppl can't o...
# 1     this bitch in wasaburger eat a burger without ...
# 2     " laura schleifer raped me as she yelled at me...
# 3     and that 's why i end up with nigger trainee d...
# 4     ? guilty to proven innocent unless you 're a j...
# ...                                                 ...
# 6119  " not for my followers to have declared the je...
# 6120  well , my dear brothers and sisters igbtq i do...
# 6121  c mon men invite it for the gay trinnies musli...
# 6122  " more and more leftists are approaching the m...
# 6123  it 's terrible looking at the world demography...
#
#                                                  franch  \
# 0     i can't access twitter how this ching chong us...
# 1     ? that bitch in whitburger eating a hamburger ...
# 2     laura loomer raped me shouting in her disgusti...
# 3     and that 's why i end up with some nigger inte...
# 4     - it 's guilty until you 're innocent unless y...
# ...                                                 ...
# 6119  do not get my disciples that the jews have dec...
# 6120  well , my dear brothers and sisters igbtq , i ...
# 6121  c my men charge for gay transnies muslim rapis...
# 6122  more and more left-wingers are getting closer ...
# 6123  it 's a horrible look at the world demography ...
#
#                                                 russian  \
# 0     i 'm confused because chinese ppl can't access...
# 1     this bitch in a burger eats a burger without a...
# 2     laura tracer raped me when she yelled at me in...
# 3     and that 's why i 'm ending up with nigger int...
# 4     guilty until proven innocent , unless you 're ...
# ...                                                 ...
# 6119  ? not so that my followers , the jews , will d...
# 6120  my dear brothers and sisters igbtech , i do no...
# 6121  ? my men press charges for gay muslim rapists ...
# 6122  ? - more and more left-wing people are approac...
# 6123  this is a terrible view of the world demograph...
#
#                                                 chinese lang
# 0     " i 'm a little confused and i can't get throu...   en
# 1     this bitch eats burgers in a burger , does n't...   en
# 2     laura loomer raped me and yelled at me in her ...   en
# 3     that 's why i ended up with black doctors , wh...   en
# 4     sin until proven innocent , unless you 're a j...   en
# ...                                                 ...  ...
# 6119  do n't let my followers , jews , declare war o...   en
# 6120  my dear igbot brothers and sisters , i do n't ...   en
# 6121  cmon men chase it for the gays rapists so that...   en
# 6122  the left is getting closer and closer to the c...   en
# 6123  well , the world 's demographers are all over ...   en
#
# [5732 rows x 11 columns]

# %%
if file_name.__contains__("toxigen"):
    transform_dict = {'muslim':'Islam','jewish':'Jewish','lgbtq':'Homosexual','black':'African',}
    df['target'] = df['target'].apply(
        lambda x: next((v for k, v in transform_dict.items() if k in re.split(' |/', x.lower())), 'other')
    )
    if file_name == "small_toxigen":
        df = df[df.toxicity_ai>=4]
        df = df[df.framing!='disagreement']
        len(df)
elif file_name.__contains__("hatexplain"):
    df = df[df['label']=='hatespeech'].reset_index(drop=True)
    df.loc[df['target']=='Arab','target'] = 'Islam'
    labels_counter = Counter(df.target.tolist())
    df.loc[~ df['target'].isin(x[0] for x in labels_counter.most_common(4)),'target'] = 'other'
elif file_name =="parler_target_annotated":
    df.target = df.target.apply(lambda x: "other" if x=="Politician" else x)

# %%
#filter by lang
def get_lang_detector(nlp, name):
    return LanguageDetector()

nlp = spacy.load("en_core_web_sm")
Language.factory("language_detector", func=get_lang_detector)
nlp.add_pipe('language_detector', last=True)
if file_name.endswith("_bt"):
    df['lang'] = df.english.apply(lambda x: nlp(x)._.language['language'])
else:
    df['lang'] = df.text.apply(lambda x: nlp(x)._.language['language'])
df = df[df['lang']=='en']

# %%
#clean data
if file_name.endswith("_bt"):
    langs = ['english', 'spanish',
       'german', 'franch', 'russian', 'chinese']
    for lang in langs:
        df[lang] = df[lang].apply(clean, no_emoji=True)
        df[lang] = df[lang].apply(normalizeTweet)
    df = pd.melt(df, id_vars=['id','target'],value_vars=langs,var_name='lang', value_name='text')
    df = df[~df.text.isin(["",'nan'])]
    df = df.dropna(axis=0)
    file_name += '_melted'
else:
    df.text = df.text.apply(clean, no_emoji=True)
    df.text = df.text.apply(normalizeTweet)

# %%
def remove_dups(post, thresh=4):
    post = post.split()
    for num_of_words in range(1, int(len(post) / thresh)):
        i = 0
        while i + num_of_words < len(post):
            orig_seq = post[i:i + num_of_words]
            j = i + num_of_words
            dif_seq = post[j: j + num_of_words]
            while j + num_of_words < len(post) and dif_seq == orig_seq:
                j += num_of_words
                dif_seq = post[j:j + num_of_words]
            if j - i > thresh * num_of_words:
                return False
            i += 1
    return True
def remove_duplicates(post):
    if not pd.isna(post):
        if remove_dups(post=post, thresh=7):
            return post
df.text = df.text.apply(remove_duplicates)

# %%
df.to_csv(fr'../data/ready_data/{file_name}.csv', encoding="utf8")

# %%
df
# Out:
#                                 id   target     lang  \
# 0      1179088797964763136_twitter    other  english
# 1      1179085312976445440_twitter    other  english
# 2                     13851720_gab   Jewish  english
# 3                     24198545_gab  African  english
# 4                     19679648_gab  African  english
# ...                            ...      ...      ...
# 34387                  9845733_gab   Jewish  chinese
# 34388                  9867117_gab    Islam  chinese
# 34389                  9875482_gab  African  chinese
# 34390                  9982674_gab    Islam  chinese
# 34391                  9992513_gab    other  chinese
#
#                                                     text
# 0      <user> i am bit confused coz chinese ppl can n...
# 1      this bitch in whataburger eating a burger with...
# 2      laura loomer raped me while screaming at me in...
# 3      and this is why i end up with nigger trainee d...
# 4      guilty until proven innocent unless you are a ...
# ...                                                  ...
# 34387  do n't let my followers , jews , declare war o...
# 34388  my dear igbot brothers and sisters , i do n't ...
# 34389  cmon men chase it for the gays rapists so that...
# 34390  the left is getting closer and closer to the c...
# 34391  well , the world ' s demographers are all over...
#
# [34374 rows x 4 columns]

# %%
df.isna().sum()
# Out:
# id        0
# target    0
# lang      0
# text      0
# dtype: int64
